# %%
class Dog():
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def bark(self):
        print(self.name, "is barking")
    
    def addYear(self):
        self.age += 1

    def getInfo(self):
        print(self.name, "is", self.age, "years old")

class Poodle(Dog):
    def __init__(self, name, age, colour):
        self.name = name
        self.age = age
        self.colour = colour
        self.weight = weight # type: ignore

    def bark(self, manner="energetically"):
        print(f"{self.name} is barking {manner}.")
    
    def getInfo(self):
        print(f"{self.name} is a {self.age} year old {self.colour} poodle and weighs {self.weight} kgs.")

class Corgi(Dog):
    def __init__(self, name, age, colour):
        self.name = name
        self.age = age
        self.colour = colour
        self.weight = weight # type: ignore

    def bark(self, manner="briefly"):
        print(f"{self.name} is barking {manner}.")
    
    def getInfo(self):
        print(f"{self.name} is a {self.age} year old {self.colour} poodle and weighs {self.weight} kgs.")

# %%
ella = Dog("ella", 3.5)
ella.getInfo()
# Out:
# ella is 3.5 years old

# %%
ella.bark()
# Out:
# ella is barking

# %%
ella.addYear()
ella.getInfo()
# Out:
# ella is 4.5 years old

# %%
ella.addYear()
ella.getInfo()
# Out:
# ella is 5.5 years old

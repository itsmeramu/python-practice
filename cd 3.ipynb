# %%
raining = input("is it raining today? (yes/no) :")
umberella = input("do you have an umberella with you ? (yes/no) :")
if raining == "yes" and umberella == "yes":
    print("dont forget your umberella when you go outside")
elif raining == "yes" and umberella == "no":
    print("dont forget to get a waterproof jacket")
# Out:
# dont forget your umberella when you go outside

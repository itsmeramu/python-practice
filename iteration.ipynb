# %%
word = "serendiptious"

vowels = ["a","e","i","o","u"]

vowel_count = 0
for charector in word:
    if charector in vowels:
        vowel_count += 1
print("Number of vowels in the word is:", vowel_count)
# Out:
# Number of vowels in the word is: 6

# %%
for i in range(1, 10, 3):
    print(i)
# Out:
# 1
# 4
# 7

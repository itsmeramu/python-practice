# %%
word = "serendipitious"

wovels = ["a","e","i","o","u"]

vowel_count = 0
for charector in word:
    if charector in wovels:
        vowel_count += 1
print("Number of vowels in the word is:", vowel_count)
# Out:
# Number of vowels in the word is: 7

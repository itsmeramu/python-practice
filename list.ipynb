# %%
n = 5 
print(n)
# Out:
# 5

# %%
listA = [5, 10, 15, 20]

# %%
print(listA)
# Out:
# [5, 10, 15, 20]

# %%
print(listA[3]) # This will print the 4th element in the list
# Out:
# 20

# %%
listA = [5, 10, 15, 20, 25]
listA[2] = 17  # This will change the 3rd element in the list to 17
print(listA)
# Out:
# [5, 10, 17, 20, 25]
